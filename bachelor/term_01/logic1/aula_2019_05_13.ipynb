# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0.0,2.0,0.01)
y = 1 + np.sin(2 * np.pi * x)
y2 = 1 + np.cos(2 * np.pi * x)

print(len(x))
print(len(y))

fig, ax = plt.subplots()

ax.plot(x,y,".",x,y2,".g")

plt.show()#para plotar no shell

print("Fim")
# Out:
# 200
# 200
# Fim
